# %%
from lib import (
    load_data,
    get_mean,
    get_median,
    get_std,
    get_quantile,
    plot_bar,
    plot_hist,
    plot_lines
)

# %%
df_salary = load_data("salaries.csv")
df_data = load_data("players.csv")
assert df_salary is not None
assert df_data is not None

# %%
df_salary
# Out:
#       league  player_id   salary   season  season_end  season_start  \
# 0        NBA  abdelal01   395000  1990-91        1991          1990
# 1        NBA  abdelal01   494000  1991-92        1992          1991
# 2        NBA  abdelal01   500000  1992-93        1993          1992
# 3        NBA  abdelal01   805000  1993-94        1994          1993
# 4        NBA  abdelal01   650000  1994-95        1995          1994
# ...      ...        ...      ...      ...         ...           ...
# 14158    NBA  zipsepa01   750000  2016-17        2017          2016
# 14159    NBA  zipsepa01  1312611  2017-18        2018          2017
# 14160    NBA  zizican01  1645200  2017-18        2018          2017
# 14161    NBA  zubaciv01  1034956  2016-17        2017          2016
# 14162    NBA  zubaciv01  1312611  2017-18        2018          2017
#
#                          team
# 0      Portland Trail Blazers
# 1      Portland Trail Blazers
# 2              Boston Celtics
# ...

# %%
df_data
# Out:
#             _id  career_PER  career_PTS  career_TRB  career_WS  career_eFG%  \
# 0     abdelal01        13.0         5.7         3.3        4.8         50.2
# 1     abdulza01        15.1         9.0         8.0       17.5          0.0
# 2     abdulka01        24.6        24.6        11.2      273.4         55.9
# 3     abdulma02        15.4        14.6         1.9       25.2         47.2
# 4     abdulta01        11.4         7.8         3.3        3.5         42.2
# ...         ...         ...         ...         ...        ...          ...
# 4680  zizican01        17.5         6.4         4.2        3.0         58.3
# 4681   zoetji01         0.8         0.3         1.1        0.1         20.0
# 4682   zopfbi01         9.6         2.2         0.9        0.1          NaN
# 4683  zubaciv01        17.6         6.9         4.6        5.3         54.0
# 4684  zunicma01         0.0         4.9         0.0        2.0          NaN
#
#      shoots weight
# 0     Right  240lb
# ...

# %%
mean_test = get_mean(df_salary, "salary")
quantile_test = get_quantile(df_salary, "salary", 0.75)
median_test = get_median(df_salary, "salary")
std_test = get_std(df_salary, "salary")
describe_test = df_salary.describe()
assert describe_test.loc["mean", "salary"] == mean_test
assert describe_test.loc["std", "salary"] == std_test
assert describe_test.loc["75%", "salary"] == quantile_test
assert 1500000 == median_test

# %%
plot_bar(df_data)

# %%
plot_hist(df_salary)

# %%
plot_lines(df_data)
